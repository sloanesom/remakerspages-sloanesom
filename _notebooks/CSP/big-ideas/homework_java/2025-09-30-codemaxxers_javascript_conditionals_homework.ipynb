# %% [raw]
# ---
# title: "Conditionals in JavaScript - Hacks"
# description: "Three scaffolded hacks to practice selection (if, else if, else) in JavaScript. No nesting."
# layout: post
# permalink: /csp/codemaxxers/conditionals/p4/hacks-js/
# ---

# %% [markdown]
# # 🌐 CSP 3.6 Hacks — Conditionals (JavaScript)
#
# You will complete **three** small programs that use selection with `if`, `else if`, `else`
#
# Answers to common errors:
# - Please select the JavaScript kernel when running the code, do NOT select python
# - If the code reports random errors try pressing restart at the top bar
# - If you get stuck on a problem, make comments about what you understand so far and what you are stuck on

# %% [markdown]
# ## 🟢 Hack 1 — Number Range Checker (Beginner)
#
# **Requirements (spec):**
# - Ask for a number.
# - If the number is **between 0 and 10** (inclusive), print the number **then** print `Goodbye`.
# - Otherwise, print only `Goodbye!`.
# - Use one `if / else` and combine comparisons with `&&`.
#
# **Tips:** use `parseInt(..., 10)`; inclusive means `>=` and `<=`.

# %%
let num = 3;  //  Change this number to test different inputs

// Number Range Checker - follow spec:
// - If number between 0 and 10 (inclusive) -> print the number then print 'Goodbye'.
// - Otherwise -> print only 'Goodbye!'.

if (num >= 0 && num <= 10) {
    console.log(num);
    console.log("Goodbye"); 
} else {
    console.log("Goodbye");

}
# Out:
#   Cell In[7], line 1
#     let num = 3;  //  Change this number to test different inputs
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 🟡 Hack 2 — Grade Evaluator (Intermediate)
#
# **Requirements (spec):**
# - Ask for a grade `0–100`.
# - If `grade >= 75`, print two lines: `You get extra credit!` then `Have a good day`.
# - Otherwise, print `Have a good day` only.

# %%
// Starter code 
let grade = 80;  // Change this grade to test different cases

// Grade Evaluator - follow spec:
// - If grade >= 75 -> print 'You get extra credit!' then 'Have a good day'.
// - Otherwise -> print 'Have a good day' only.

grade = parseInt(grade, 10);
if (Number.isFinite(grade) && grade >= 75) {
  console.log('You get extra credit!');
  console.log('Have a good day');
} else {
  console.log('Have a good day');
}

# %% [markdown]
# ## 🔵 Hack 3 — Access Pass (Advanced)
#
# **Inputs:** `age` (number), `has_ticket` (`"yes"/"no"`), `vip` (`"yes"/"no"`)
#
# **Rules**
# - If `vip === "yes"` → `VIP Entrance`
# - Else if `has_ticket === "yes"` **and** `age >= 16` → `General Entrance`
# - Else if `has_ticket === "yes"` **and** `age < 16` → `Minor Entrance (with guardian)`
# - Else → `No Entrance`
#
# **Tip:** normalize strings with `.trim().toLowerCase()`.

# %%
// Starter code (student edits this cell)
let age = 15;           //  Change the age
let has_ticket = "yes"; //  Change to "yes" or "no"
let vip = "no";         //  Change to "yes" or "no"

// Access Pass ladder - follow rules exactly:
// - VIP === 'yes' -> 'VIP Entrance'
// - else if has_ticket === 'yes' and age >= 16 -> 'General Entrance'
// - else if has_ticket === 'yes' and age < 16 -> 'Minor Entrance (with guardian)'
// - else -> 'No Entrance'

// Normalize string inputs to be safe
let ticketNormalized = String(has_ticket).trim().toLowerCase();
let vipNormalized = String(vip).trim().toLowerCase();

if (vipNormalized === 'yes') {
  console.log('VIP Entrance');
} else if (ticketNormalized === 'yes' && age >= 16) {
  console.log('General Entrance');
} else if (ticketNormalized === 'yes' && age < 16) {
  console.log('Minor Entrance (with guardian)');
} else {
  console.log('No Entrance');
}

# %% [markdown]
# ---
# ### Reflection: Think about the following question. Answer in 3-4 sentences
#
# - Did any of the question trip you up? If yes, explain the problem and your solution. If no, give a brief, 1-2 sentence summary of conditionals.
#
# I did not get tripped up by the logic. The main challenge is remembering inclusive comparisons and the correct order for if / else if branches so the most specific cases run first. Conditionals let the program choose which path to take based on boolean expressions. Practicing small ladders helped solidify how to order checks and normalize inputs.
#
# - Can you think of real life examples where we would use conditionals? Please do NOT use one of the hacks as a real life example
#
# Real-life examples: deciding whether to bring an umbrella (if it's raining) and selecting a movie rating filter (if user is under certain age).
#
# - How is javascript different from python in terms of conditionals?
#
# JavaScript uses parentheses around conditions and braces for blocks (if (cond) { ... }), while Python uses colons and indentation (if cond: ...). JS requires explicit true/false values and type conversions are more permissive, so it's common to normalize inputs in JS.

# %% [markdown]
# ---
# ### 🧾 Turn-in checklist
# - [x] All three hacks run and match the rules above them.
# - [x] You included at least one changed element for at least one hack (I normalized input strings in Hack 3 and added input parsing in Hack 1 & 2).
# - [x] You wrote a 2–3 sentence reflection in your portfolio:
#   - Most used conditional form: if / else if / else ladder.
#   - What I would add: more examples showing order-of-check importance and common normalization pitfalls.
